# %% [markdown]
# # The numpy random package
# ***
# Numpy stands for Numerical Python and is a open source project, The library contains multiple number arrays and has collections of ways to sort those arrays. Numpy is made by Travis Oliphant which contains both numarray and numeric.
# Numpy can be used for math and logical operations on arrays. It can also be used to work on linear algebra, Numpy has functions build in for these kind of operation.
#
# [Official Docs](https://numpy.org/doc/stable/reference/random/index.html)
# ***
# ### Quick points on Numpy
# - Bit Generators: Objects that gen random numbers from using unsigned int words and are filled with either 32 or 64 bits.
# - It comes from the library called **[Numeric](https://docs.python.org/3/library/numeric.html)** Which was made by Jim Huguinin. Click link for more information on Numeric.
# - It has also replaced mathLab, Numpy is said to be a more complete and modern way of programming.
# ***

# %%
#imports of numpy and plotting.
import numpy as np
import matplotlib.pyplot as plt

#Plot figure style
plt.style.use('seaborn-dark-palette')

#Changing the default size of the figure.
plt.rcParams['figure.figsize'] = [20, 10]

# %%
mu, sigma = 0,0.1 #mean and standard deviation.
s = np.random.normal(mu,sigma, 1000)

# %%
#Checking the length of s.
len(s)
# Out:
# 1000

# %%
#cutting s down to a size that is readable for the user.
#the ':' will give you the numbers from index 0 to 49(50)
s[:50]
# Out:
# array([-0.06369924,  0.12772233,  0.02566825, -0.13377048,  0.01724279,
#         0.18981292, -0.19231289,  0.03894777, -0.04758129, -0.07414774,
#         0.11175526, -0.08123115,  0.09008986, -0.02059889,  0.02138912,
#         0.04020434,  0.05004569,  0.03459059, -0.09380222,  0.00623606,
#        -0.03973749,  0.04707299, -0.06200253, -0.15750523, -0.1557234 ,
#         0.12324305, -0.03246073, -0.02711241,  0.09981619, -0.02948749,
#        -0.04944524, -0.12933906,  0.15658858,  0.01783379, -0.09119248,
#        -0.12369113, -0.09588114, -0.02811781,  0.02558466,  0.13921552,
#        -0.03387823, -0.17564617, -0.09412408, -0.04205511,  0.14452177,
#         0.06876151,  0.12717635, -0.10191583,  0.10321316,  0.02608475])

# %%
abs(mu - np.mean(s))
# Out:
# 0.001054945698654973

# %%
abs(sigma - np.std(s,ddof=1))
# Out:
# 0.0015616126740159997

# %%
count, bins, ignored = plt.hist(s, 30, density = True)# hist is short for histogram
x = 1/(sigma * np.sqrt(2 * np.pi)) * np.exp(-(bins - mu)**2/(2 * sigma**2))#here I am following the pep8 docs
plt.plot(bins,x,linewidth=2, color='y')
plt.show()

# %% [markdown]
# ## References
# - [Pep8](https://www.python.org/dev/peps/pep-0008/) is for the coding style in Python
# ***

# %% [markdown]
# ## End
